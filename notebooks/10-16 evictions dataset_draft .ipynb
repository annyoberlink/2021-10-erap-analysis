# %%
import pandas as pd

# %%
pd.read_csv("ERAP_Data_Zipcode_County.csv")
# Out:
#        County          Zipcode Rent Arrears Applications  \
# 0    New York            10001                       408
# 1    New York            10002                     1,260
# 2    New York            10003                       302
# 3    New York            10004                        37
# 4    New York            10005                        80
# ..        ...              ...                       ...
# 187    Queens            11692                       863
# 188    Queens            11693                       273
# 189    Queens            11694                       271
# 190    Queens            11697                         1
# 191     Bronx  Unspecified Zip                       123
#
#     Prospective Rent Applications Utility Arrears Applications  \
# 0                             322                           50
# 1                             991                          110
# 2                             257                           58
# ...
